# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from pyiceberg.catalog import load_catalog
from dotenv import load_dotenv
import os
import datetime
import requests

load_dotenv()

client_id = os.getenv("STREAMS_CHARTS_CLINET_ID")
token = os.getenv("STREAMS_CHARTS_TOKEN")
s3_bucket = os.getenv("S3_BUCKET")
s3_prefix = os.getenv("S3_PREFIX")
glue_database = os.getenv("GLUE_DATABASE")
glue_table = os.getenv("GLUE_TABLE")

url = "https://streamscharts.com/api/jazz/channels?platform=twitch&time=7-days"
headers = {"Client-ID": client_id, "Token": token}
response = requests.get(url, headers=headers)

if not response.status_code == 200:
    print(f"Failed to retrieve data: {response.status_code}")
    exit()


data = response.json()
df = pd.DataFrame(data['data'])

start_date = datetime.datetime.today().date() - datetime.timedelta(days=datetime.datetime.today().weekday())
end_date = start_date + datetime.timedelta(days=6)
week_number = start_date.isocalendar()[1]
year = start_date.year

df['start_date'] = start_date
df['end_date'] = end_date
df['year'] = year
df['week_number'] = week_number

# %%
df
# Out:
#    platform  channel_name channel_display_name channel_id  hours_watched  \
# 0    twitch      kaicenat             KaiCenat  641972806       19385765
# 1    twitch     auronplay            auronplay  459331509        3236050
# 2    twitch        rubius               Rubius   39276140        1993621
# 3    twitch      eliasn97             eliasn97  238813810        1699649
# 4    twitch      rainbow6             Rainbow6   65171890        1581562
# ..      ...           ...                  ...        ...            ...
# 95   twitch        gronkh               GRONKH   12875057         347556
# 96   twitch        quin69               Quin69   56649026         347405
# 97   twitch  plaqueboymax         plaqueboymax  672238954         345320
# 98   twitch          mira                 mira   79294007         344654
# 99   twitch    thebausffs           Thebausffs   93869876         342876
#
#     peak_viewers  average_viewers  airtime_in_m  followers_gain live_views  \
# 0         272552           115622         10060          409115       None
# 1         277925           133446          1455           70559   20305995
# 2         226606            62301          1920           54826   14246963
# 3          86661            36228          2815            4043     650500
# 4          66571            30222          3140           15451    3284661
# ..           ...              ...           ...             ...        ...
# 95         41457            21610           965            1558       None
# 96         10974             6903          3020            1105     227264
# 97         22208            12153          1705           10202       None
# 98          3434             2057         10060            2164       None
# 99         18534            12700          1620            3528       None
#
#                 last_streamed_game  \
# 0                    Just Chatting
# 1                        Minecraft
# 2                        Minecraft
# 3                   Special Events
# 4   Tom Clancy's Rainbow Six Siege
# ..                             ...
# 95                   Just Chatting
# 96                       Magicraft
# 97                   Just Chatting
# 98                   Just Chatting
# 99               League of Legends
#
#                                            avatar_url channel_country  \
# 0   https://static-cdn.jtvnw.net/jtv_user_pictures...              US
# 1   https://static-cdn.jtvnw.net/jtv_user_pictures...              ES
# 2   https://static-cdn.jtvnw.net/jtv_user_pictures...              ES
# 3   https://static-cdn.jtvnw.net/jtv_user_pictures...              DE
# 4   https://static-cdn.jtvnw.net/jtv_user_pictures...            None
# ..                                                ...             ...
# 95  https://static-cdn.jtvnw.net/jtv_user_pictures...              DE
# 96  https://static-cdn.jtvnw.net/jtv_user_pictures...              NZ
# 97  https://static-cdn.jtvnw.net/jtv_user_pictures...              US
# 98  https://static-cdn.jtvnw.net/jtv_user_pictures...              RU
# 99  https://static-cdn.jtvnw.net/jtv_user_pictures...              SE
#
#    stream_language partnership_status  channel_type  start_date    end_date  \
# 0               en            partner          Male  2024-11-18  2024-11-24
# 1               es            partner          Male  2024-11-18  2024-11-24
# 2               es            partner          Male  2024-11-18  2024-11-24
# 3               de            partner          Male  2024-11-18  2024-11-24
# 4               en            partner  Organization  2024-11-18  2024-11-24
# ..             ...                ...           ...         ...         ...
# 95              de            partner          Male  2024-11-18  2024-11-24
# 96              en            partner          Male  2024-11-18  2024-11-24
# 97              en            partner          Male  2024-11-18  2024-11-24
# 98              en            partner        Female  2024-11-18  2024-11-24
# 99              en            partner          Male  2024-11-18  2024-11-24
#
#     year  week_number
# 0   2024           47
# 1   2024           47
# 2   2024           47
# 3   2024           47
# 4   2024           47
# ..   ...          ...
# 95  2024           47
# 96  2024           47
# 97  2024           47
# 98  2024           47
# 99  2024           47
#
# [100 rows x 20 columns]

# %%
from pyiceberg.catalog import load_catalog
from dotenv import load_dotenv
import os

load_dotenv()

client_id = os.getenv("STREAMS_CHARTS_CLINET_ID")
token = os.getenv("STREAMS_CHARTS_TOKEN")
s3_bucket = os.getenv("S3_BUCKET")
s3_prefix = os.getenv("S3_PREFIX")
glue_database = os.getenv("GLUE_DATABASE")
glue_table = os.getenv("GLUE_TABLE")

# Load Iceberg catalog and table
catalog = load_catalog(
    "glue",
    **{
        "type": "GLUE",
        "glue.region": "eu-west-2",
    }
)
table = catalog.load_table(f"{glue_database}.{glue_table}")
